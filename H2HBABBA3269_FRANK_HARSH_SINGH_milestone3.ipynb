# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import OneHotEncoder,LabelEncoder,OrdinalEncoder
from xgboost import XGBClassifier

import  matplotlib.pyplot as plt
import seaborn as sns
import sklearn



# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv('H2HBABBA3269.csv')

# %%
data
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200792293      UNIFIE systems  2019-02-28 00:00:00
# 1              U001  0200782669              SYGMA   2019-01-31 00:00:00
# 2              U001  0200726979           BJ'S  llc                  NaN
# 3              U001  0200865666   RESTAU associates  2019-09-03 00:00:00
# 4              U001  0200732755           KROGER in  2019-09-03 00:00:00
# ...             ...         ...                 ...                  ...
# 49995          U001  0200719300  SYSTEMS associates  2019-07-31 00:00:00
# 49996          U001  0200769623          WAL-MAR co                  NaN
# 49997          U001  0200769623          WAL-MAR in                  NaN
# 49998          U001  0200762301             C&S WH                   NaN
# 49999          U001  0200769623     WAL-MAR systems  2019-10-30 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2019.0  1.928797e+09   2019-02-13              20190214
# 1             2019.0  1.928581e+09   2019-01-10              20190107
# 2             2020.0  1.930587e+09   2020-03-03              20200302
# 3             2019.0  1.929735e+09   2019-08-19              20190812
# 4             2019.0  1.929753e+09   2019-08-18              20190816
# ...              ...           ...          ...                   ...
# 49995         2019.0  1.929619e+09   2019-07-15              20190713
# 49996         2020.0  1.930799e+09   2020-04-18              20200418
# 49997         2020.0  1.930859e+09   2020-05-05              20200505
# 49998         2020.0  1.930754e+09   2020-04-06              20200406
# 49999         2019.0  1.930028e+09   2019-10-18              20191018
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 0                    20190213   20190228.0              USD            RV
# 1                    20190110   20190211.0              USD            RV
# 2                    20200303   20200318.0              USD            RV
# 3                    20190819   20190903.0              USD            RV
# 4                    20190818   20190902.0              USD            RV
# ...                       ...          ...              ...           ...
# 49995                20190715   20190730.0              USD            RV
# 49996                20200418   20200503.0              USD            RV
# 49997                20200505   20200520.0              USD            RV
# 49998                20200406   20200421.0              USD            RV
# 49999                20191018   20191102.0              USD            RV
#
#        posting_id  area_business  total_open_amount  baseline_create_date  \
# 0             1.0            NaN           25193.80            20190213.0
# 1             1.0            NaN           43960.21            20190110.0
# 2             1.0            NaN             336.08            20200303.0
# 3             1.0            NaN             670.08            20190819.0
# 4             1.0            NaN           54616.65            20190818.0
# ...           ...            ...                ...                   ...
# 49995         1.0            NaN            2568.00            20190715.0
# 49996         1.0            NaN            2325.38            20200418.0
# 49997         1.0            NaN           44462.63            20200505.0
# 49998         1.0            NaN           74067.22            20200406.0
# 49999         1.0            NaN           36711.56            20191018.0
#
#       cust_payment_terms    invoice_id  isOpen
# 0                   NAA8  1.928797e+09       0
# 1                   NA32  1.928581e+09       0
# 2                   NAA8  1.930587e+09       1
# 3                   NAA8  1.929735e+09       0
# 4                   NAA8  1.929753e+09       0
# ...                  ...           ...     ...
# 49995               NAA8  1.929619e+09       0
# 49996               NAH4  1.930799e+09       1
# 49997               NAH4  1.930859e+09       1
# 49998               NAC6  1.930754e+09       1
# 49999               NAH4  1.930028e+09       0
#
# [50000 rows x 19 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   business_code           50000 non-null  object
#  1   cust_number             50000 non-null  object
#  2   name_customer           50000 non-null  object
#  3   clear_date              40000 non-null  object
#  4   buisness_year           50000 non-null  float64
#  5   doc_id                  50000 non-null  float64
#  6   posting_date            50000 non-null  object
#  7   document_create_date    50000 non-null  int64
#  8   document_create_date.1  50000 non-null  int64
#  9   due_in_date             50000 non-null  float64
#  10  invoice_currency        50000 non-null  object
#  11  document type           50000 non-null  object
#  12  posting_id              50000 non-null  float64
#  13  area_business           0 non-null      float64
#  14  total_open_amount       50000 non-null  float64
#  15  baseline_create_date    50000 non-null  float64
#  16  cust_payment_terms      50000 non-null  object
#  17  invoice_id              49999 non-null  float64
#  18  isOpen                  50000 non-null  int64
# dtypes: float64(8), int64(3), object(8)
# memory usage: 7.2+ MB

# %%
data.isna().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# area_business             50000
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    1
# isOpen                        0
# dtype: int64

# %% [markdown]
# # Removing Nan Columns

# %%
#since area_buisness in NaN we drop it
data=data.drop(columns=['area_business'])

# %%
data.shape
# Out:
# (50000, 18)

# %% [markdown]
# # Spilliting the data

# %%
main_train = data[data.clear_date.isnull()==False]
main_test = data[data.clear_date.isnull()]

# %%
data.isna().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    1
# isOpen                        0
# dtype: int64

# %%
main_train=main_train.dropna()

# %% [markdown]
# # Droping contants features

# %%
# droping the constant features i.e document type ,posting_id,is_open
main_train = main_train.drop(columns = ['isOpen', 'posting_id','document type'])

# %%
main_train
# Out:
#       business_code cust_number       name_customer           clear_date  \
# 0              U001  0200792293      UNIFIE systems  2019-02-28 00:00:00
# 1              U001  0200782669              SYGMA   2019-01-31 00:00:00
# 3              U001  0200865666   RESTAU associates  2019-09-03 00:00:00
# 4              U001  0200732755           KROGER in  2019-09-03 00:00:00
# 5              U001  0200759878       SA foundation  2019-05-03 00:00:00
# ...             ...         ...                 ...                  ...
# 49990          U001  0200769623          WAL-MAR us  2019-10-09 00:00:00
# 49991          U001  0200797452           US  trust  2019-05-06 00:00:00
# 49992          U001   200744019            TARG llc  2019-07-23 00:00:00
# 49995          U001  0200719300  SYSTEMS associates  2019-07-31 00:00:00
# 49999          U001  0200769623     WAL-MAR systems  2019-10-30 00:00:00
#
#        buisness_year        doc_id posting_date  document_create_date  \
# 0             2019.0  1.928797e+09   2019-02-13              20190214
# 1             2019.0  1.928581e+09   2019-01-10              20190107
# 3             2019.0  1.929735e+09   2019-08-19              20190812
# 4             2019.0  1.929753e+09   2019-08-18              20190816
# 5             2019.0  1.929167e+09   2019-04-18              20190418
# ...              ...           ...          ...                   ...
# 49990         2019.0  1.929932e+09   2019-09-29              20190929
# 49991         2019.0  1.929175e+09   2019-04-20              20190419
# 49992         2019.0  1.929566e+09   2019-07-04              20190702
# 49995         2019.0  1.929619e+09   2019-07-15              20190713
# 49999         2019.0  1.930028e+09   2019-10-18              20191018
#
#        document_create_date.1  due_in_date invoice_currency  \
# 0                    20190213   20190228.0              USD
# 1                    20190110   20190211.0              USD
# 3                    20190819   20190903.0              USD
# 4                    20190818   20190902.0              USD
# 5                    20190418   20190503.0              USD
# ...                       ...          ...              ...
# 49990                20190929   20191014.0              USD
# 49991                20190420   20190505.0              USD
# 49992                20190704   20190719.0              USD
# 49995                20190715   20190730.0              USD
# 49999                20191018   20191102.0              USD
#
#        total_open_amount  baseline_create_date cust_payment_terms  \
# 0               25193.80            20190213.0               NAA8
# 1               43960.21            20190110.0               NA32
# 3                 670.08            20190819.0               NAA8
# 4               54616.65            20190818.0               NAA8
# 5               57821.30            20190418.0               NAH4
# ...                  ...                   ...                ...
# 49990           39061.29            20190929.0               NAH4
# 49991           34774.40            20190420.0               NAA8
# 49992            4769.89            20190704.0               NAA8
# 49995            2568.00            20190715.0               NAA8
# 49999           36711.56            20191018.0               NAH4
#
#          invoice_id
# 0      1.928797e+09
# 1      1.928581e+09
# 3      1.929735e+09
# 4      1.929753e+09
# 5      1.929167e+09
# ...             ...
# 49990  1.929932e+09
# 49991  1.929175e+09
# 49992  1.929566e+09
# 49995  1.929619e+09
# 49999  1.930028e+09
#
# [39999 rows x 15 columns]

# %% [markdown]
# # Removing Duplicate columns

# %%
#remove duplicate columns since invoice id and documnet id are the same

main_train= main_train.drop(columns=['doc_id'])

# %% [markdown]
# # Removing column having unique entries

# %%
# now since invice id in unique so we are going to drop it
main_train=main_train.drop(columns='invoice_id')

# %% [markdown]
# # Removing Irrelevent Columns

# %%
#now we are going to remove irrelevant columns which not effect predict model
main_train=main_train.drop(columns=['name_customer','document_create_date'])

# %%
main_train
# Out:
#       business_code cust_number           clear_date  buisness_year  \
# 0              U001  0200792293  2019-02-28 00:00:00         2019.0
# 1              U001  0200782669  2019-01-31 00:00:00         2019.0
# 3              U001  0200865666  2019-09-03 00:00:00         2019.0
# 4              U001  0200732755  2019-09-03 00:00:00         2019.0
# 5              U001  0200759878  2019-05-03 00:00:00         2019.0
# ...             ...         ...                  ...            ...
# 49990          U001  0200769623  2019-10-09 00:00:00         2019.0
# 49991          U001  0200797452  2019-05-06 00:00:00         2019.0
# 49992          U001   200744019  2019-07-23 00:00:00         2019.0
# 49995          U001  0200719300  2019-07-31 00:00:00         2019.0
# 49999          U001  0200769623  2019-10-30 00:00:00         2019.0
#
#       posting_date  document_create_date.1  due_in_date invoice_currency  \
# 0       2019-02-13                20190213   20190228.0              USD
# 1       2019-01-10                20190110   20190211.0              USD
# 3       2019-08-19                20190819   20190903.0              USD
# 4       2019-08-18                20190818   20190902.0              USD
# 5       2019-04-18                20190418   20190503.0              USD
# ...            ...                     ...          ...              ...
# 49990   2019-09-29                20190929   20191014.0              USD
# 49991   2019-04-20                20190420   20190505.0              USD
# 49992   2019-07-04                20190704   20190719.0              USD
# 49995   2019-07-15                20190715   20190730.0              USD
# 49999   2019-10-18                20191018   20191102.0              USD
#
#        total_open_amount  baseline_create_date cust_payment_terms
# 0               25193.80            20190213.0               NAA8
# 1               43960.21            20190110.0               NA32
# 3                 670.08            20190819.0               NAA8
# 4               54616.65            20190818.0               NAA8
# 5               57821.30            20190418.0               NAH4
# ...                  ...                   ...                ...
# 49990           39061.29            20190929.0               NAH4
# 49991           34774.40            20190420.0               NAA8
# 49992            4769.89            20190704.0               NAA8
# 49995            2568.00            20190715.0               NAA8
# 49999           36711.56            20191018.0               NAH4
#
# [39999 rows x 11 columns]

# %%
main_train.nunique()
# Out:
# business_code                 6
# cust_number                1350
# clear_date                  397
# buisness_year                 2
# posting_date                422
# document_create_date.1      422
# due_in_date                 489
# invoice_currency              2
# total_open_amount         35527
# baseline_create_date        431
# cust_payment_terms           72
# dtype: int64

# %% [markdown]
# # Date Time Conversion

# %%
main_train['document_create_date.1']=pd.to_datetime(main_train['document_create_date.1'], format='%Y%m%d')
main_train['due_in_date']=pd.to_datetime(main_train['due_in_date'], format='%Y%m%d')
main_train['baseline_create_date']=pd.to_datetime(main_train['baseline_create_date'], format='%Y%m%d')
main_train['clear_date']=pd.to_datetime(main_train['clear_date']).dt.date  #removing the time part sice its zero evrywhere
main_train['clear_date']=pd.to_datetime(main_train.clear_date) #string object to datetime

# %%
main_train['posting_date']=pd.to_datetime(main_train['posting_date'])

# %% [markdown]
# # Sorting the entries by Posting date

# %%
main_train.sort_values(by=['posting_date'],inplace=True)

# %% [markdown]
# # #some invoices are created before  baseline create date so we are removing those here Kind of Outlier

# %%
temp = pd.Series(main_train['document_create_date.1'] - main_train['baseline_create_date']).dt.days

# %%
rows_to_drop = temp.value_counts().to_frame(name = 'count')

# %%
# No. of rows to drop satisfying the condition
rows_to_drop[(rows_to_drop.index <0)].sum()
# Out:
# count    2545
# dtype: int64

# %%
main_train = main_train[((temp==0) | (temp>0))].reset_index(drop=True)

# %%
#now removing document_create_date.1 date since all the are now coreect 
main_train = main_train.drop(columns = ['document_create_date.1'])

# %%
main_train.dtypes , main_train.shape
# Out:
# (business_code                   object
#  cust_number                     object
#  clear_date              datetime64[ns]
#  buisness_year                  float64
#  posting_date            datetime64[ns]
#  due_in_date             datetime64[ns]
#  invoice_currency                object
#  total_open_amount              float64
#  baseline_create_date    datetime64[ns]
#  cust_payment_terms              object
#  dtype: object,
#  (37454, 10))

# %% [markdown]
# # Adding column like payemnt term delay due term in the main_train

# %%
main_train['payment_term']=pd.Series(main_train['clear_date'] - main_train['baseline_create_date']).dt.days
main_train['due_term']=pd.Series(main_train['due_in_date'] - main_train['baseline_create_date']).dt.days
main_train['delay'] = main_train['payment_term'] - main_train['due_term']

# %%
main_train = main_train.drop(columns = ['clear_date'])

# %%
main_train
# Out:
#       business_code cust_number  buisness_year posting_date due_in_date  \
# 0              U001  0200769623         2019.0   2018-12-30  2019-01-14
# 1              U001  0200794332         2019.0   2018-12-30  2019-01-14
# 2              U001  0200769623         2019.0   2018-12-30  2019-01-14
# 3              U001  0200726979         2019.0   2018-12-30  2019-01-14
# 4              U001  0200014556         2019.0   2018-12-30  2019-01-14
# ...             ...         ...            ...          ...         ...
# 37449          U001  0200780383         2020.0   2020-02-27  2020-03-13
# 37450          U001  0200759878         2020.0   2020-02-27  2020-03-13
# 37451          U001  0200721330         2020.0   2020-02-27  2020-03-08
# 37452          U001  0200759878         2020.0   2020-02-27  2020-03-13
# 37453          U001  0200721330         2020.0   2020-02-27  2020-03-08
#
#       invoice_currency  total_open_amount baseline_create_date  \
# 0                  USD             580.67           2018-12-30
# 1                  USD           15284.38           2018-12-30
# 2                  USD           28485.61           2018-12-30
# 3                  USD             186.40           2018-12-30
# 4                  USD           69249.78           2018-12-30
# ...                ...                ...                  ...
# 37449              USD           48029.58           2020-02-27
# 37450              USD           65988.21           2020-02-27
# 37451              USD           77434.89           2020-02-27
# 37452              USD           65988.21           2020-02-27
# 37453              USD           77434.89           2020-02-27
#
#       cust_payment_terms  payment_term  due_term  delay
# 0                   NAH4            10        15     -5
# 1                   NAAX            16        15      1
# 2                   NAH4            10        15     -5
# 3                   NAA8            16        15      1
# 4                   NAA8            15        15      0
# ...                  ...           ...       ...    ...
# 37449               NAA8            19        15      4
# 37450               NAH4            15        15      0
# 37451               NA10            14        10      4
# 37452               NAH4            15        15      0
# 37453               NA10            14        10      4
#
# [37454 rows x 12 columns]

# %%
#No direct trend
sns.scatterplot(data=main_train, x="payment_term", y="posting_date")
# Out:
# <AxesSubplot:xlabel='payment_term', ylabel='posting_date'>

# %% [markdown]
# # Oulier Removal

# %%
payment_max = 100
main_train[main_train['payment_term']>=payment_max]['payment_term'].value_counts().sum()
# Out:
# 128

# %%
main_train = main_train[(main_train['total_open_amount'] > 1) & (main_train['payment_term']<=payment_max)].reset_index(drop=True)

# %%
main_train.shape
# Out:
# (37327, 12)

# %%
#now droping payment term beacuse cant use in main test clear date is none there
main_train = main_train.drop(columns = ['payment_term'])

# %% [markdown]
# # Split Data

# %%
# Converting the main_train into X and y so that we can pass it onto train_test_split function

# X --> contains the dataframe without the target i.e payment_term
X = main_train.drop('delay',axis=1)

# y --> contains only the target value 
y = main_train['delay']

# %%
#splitting the data first into two part -- doing a 70:30 split i.e 30% data fed to intermediate test data set
from sklearn.model_selection import train_test_split
X_train,X_inter_test,y_train,y_inter_test = train_test_split(X,y,test_size=0.3,random_state=0 , shuffle = False)

# %%
X_val,X_test,y_val,y_test = train_test_split(X_inter_test,y_inter_test,test_size=0.5,random_state=0 , shuffle = False)

# %%
X_train.shape , X_val.shape , X_test.shape
# Out:
# ((26128, 10), (5599, 10), (5600, 10))

# %% [markdown]
# # EDA

# %%
# distribution of the target column 
# slight skewed distribution
# outliers present but not that significant , hence  
sns.distplot(y_train)
# Out:
# <AxesSubplot:xlabel='delay', ylabel='Density'>

# %%
#No direct trend
sns.scatterplot(data=X_train.merge(y_train,on = X_train.index), x="delay", y="posting_date")
# Out:
# <AxesSubplot:xlabel='delay', ylabel='posting_date'>

# %% [markdown]
# # Feature Engineering

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 26128 entries, 0 to 26127
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   business_code         26128 non-null  object
#  1   cust_number           26128 non-null  object
#  2   buisness_year         26128 non-null  float64
#  3   posting_date          26128 non-null  datetime64[ns]
#  4   due_in_date           26128 non-null  datetime64[ns]
#  5   invoice_currency      26128 non-null  object
#  6   total_open_amount     26128 non-null  float64
#  7   baseline_create_date  26128 non-null  datetime64[ns]
#  8   cust_payment_terms    26128 non-null  object
#  9   due_term              26128 non-null  int64
# dtypes: datetime64[ns](3), float64(2), int64(1), object(4)
# memory usage: 2.2+ MB

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
invoice_currency_encoder = LabelEncoder()
invoice_currency_encoder.fit(X_train['invoice_currency'])
X_train['invoice_currency'] = invoice_currency_encoder.transform(X_train['invoice_currency'])

# %%
X_val['invoice_currency'] = invoice_currency_encoder.transform(X_val['invoice_currency'])
X_test['invoice_currency'] = invoice_currency_encoder.transform(X_test['invoice_currency'])

# %%
business_code_encoder = LabelEncoder()
business_code_encoder.fit(X_train['business_code'])
X_train['business_code'] = business_code_encoder.transform(X_train['business_code'])

# %%
X_val['business_code'] = business_code_encoder.transform(X_val['business_code'])
X_test['business_code'] = business_code_encoder.transform(X_test['business_code'])

# %%
cust_number_encoder = LabelEncoder()
cust_number_encoder.fit(X_train['cust_number'])
X_train['cust_number'] = cust_number_encoder.transform(X_train['cust_number'])

# %%
# finding what are the new catagories in the validation set
diff = set(X_val['cust_number'])-set(cust_number_encoder.classes_)

# adding them to the classess variable // 
for items in diff:
    cust_number_encoder.classes_ = np.append(cust_number_encoder.classes_,items)

# %%
X_val['cust_number'] = cust_number_encoder.transform(X_val['cust_number'])

# %%
# doing same thing for test also

diff1 = set(X_test['cust_number'])-set(cust_number_encoder.classes_)

# adding them to the classess variable // 
for items in diff1:
    cust_number_encoder.classes_ = np.append(cust_number_encoder.classes_,items)

# %%
X_test['cust_number'] = cust_number_encoder.transform(X_test['cust_number'])

# %%
cust_payment_terms_encoder = LabelEncoder()
cust_payment_terms_encoder.fit(X_train['cust_payment_terms'])
X_train['cust_payment_terms'] = cust_payment_terms_encoder.transform(X_train['cust_payment_terms'])

# %%
# finding what are the new catagories in the validation set
diff3 = set(X_val['cust_payment_terms'])-set(cust_payment_terms_encoder.classes_)

# adding them to the classess variable // 
for items in diff3:
    cust_payment_terms_encoder.classes_ = np.append(cust_payment_terms_encoder.classes_,items)

# %%
X_val['cust_payment_terms'] = cust_payment_terms_encoder.transform(X_val['cust_payment_terms'])

# %%
diff4 = set(X_test['cust_payment_terms'])-set(cust_payment_terms_encoder.classes_)

# adding them to the classess variable // 
for items in diff4:
    cust_payment_terms_encoder.classes_ = np.append(cust_payment_terms_encoder.classes_,items)

# %%
X_test['cust_payment_terms'] = cust_payment_terms_encoder.transform(X_test['cust_payment_terms'])

# %%
X_train.dtypes
# Out:
# business_code                    int32
# cust_number                      int32
# buisness_year                  float64
# posting_date            datetime64[ns]
# due_in_date             datetime64[ns]
# invoice_currency                 int32
# total_open_amount              float64
# baseline_create_date    datetime64[ns]
# cust_payment_terms               int32
# due_term                         int64
# dtype: object

# %%
X_train=X_train.drop(columns=['posting_date'])
X_val=X_val.drop(columns=['posting_date'])
X_test=X_test.drop(columns=['posting_date'])

# %% [markdown]
# ### Splitting dates into days moth year

# %%
def helper_map(col ,traindf = X_train,valdf = X_val,testdf = X_test):
    traindf.drop(col, axis =1,inplace=True)
    valdf.drop(col,axis=1 , inplace=True)
    testdf.drop(col,axis=1 , inplace=True)

    return traindf,valdf ,testdf

# %%
X_train['due_in_date.days'] = X_train['due_in_date'].dt.day
X_train['due_in_date.month'] = X_train['due_in_date'].dt.month
X_train['due_in_date.year'] = X_train['due_in_date'].dt.year

X_val['due_in_date.days'] = X_val['due_in_date'].dt.day
X_val['due_in_date.month'] = X_val['due_in_date'].dt.month
X_val['due_in_date.year'] = X_val['due_in_date'].dt.year

X_test['due_in_date.days'] = X_test['due_in_date'].dt.day
X_test['due_in_date.month'] = X_test['due_in_date'].dt.month
X_test['due_in_date.year'] = X_test['due_in_date'].dt.year

# %%
X_train ,X_val, X_test = helper_map(['due_in_date'])

# %%
X_train['baseline_create_date.days'] = X_train['baseline_create_date'].dt.day
X_train['baseline_create_date.month'] = X_train['baseline_create_date'].dt.month
X_train['baseline_create_date.year'] = X_train['baseline_create_date'].dt.year

X_val['baseline_create_date.days'] = X_val['baseline_create_date'].dt.day
X_val['baseline_create_date.month'] = X_val['baseline_create_date'].dt.month
X_val['baseline_create_date.year'] = X_val['baseline_create_date'].dt.year

X_test['baseline_create_date.days'] = X_test['baseline_create_date'].dt.day
X_test['baseline_create_date.month'] = X_test['baseline_create_date'].dt.month
X_test['baseline_create_date.year'] = X_test['baseline_create_date'].dt.year

# %%
X_train ,X_val, X_test = helper_map(['baseline_create_date'])

# %%
X_train.reset_index(drop=True,inplace=True)

# %% [markdown]
# # Feature Selection

# %%
#Feature Selection

#corrmat = X_train.merge(y_train , on = X_train.index).corr()
# plt.subplots(figsize=(12,9))
# sns.heatmap(corrmat, vmax=0.9, square=True)


colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(X_train.merge(y_train , on = X_train.index ).corr(),linewidths=0.1,vmax=1.0, 
            square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <AxesSubplot:title={'center':'Pearson Correlation of Features'}>

# %% [markdown]
# ### Here we can see buisnes_year , clear_date_year are constant columns and should be removed

# %%
X_train=X_train.drop(columns=['buisness_year'])
X_val=X_val.drop(columns=['buisness_year'])
X_test=X_test.drop(columns=['buisness_year'])

# %%
X_train
# Out:
#        business_code  cust_number  invoice_currency  total_open_amount  \
# 0                  1          656                 1             580.67
# 1                  1          724                 1           15284.38
# 2                  1          656                 1           28485.61
# 3                  1          564                 1             186.40
# 4                  1          288                 1           69249.78
# ...              ...          ...               ...                ...
# 26123              1          737                 1              70.80
# 26124              1         1116                 1            3956.54
# 26125              1          545                 1            3382.80
# 26126              1         1114                 1           26520.00
# 26127              1          656                 1            1898.20
#
#        cust_payment_terms  due_term  due_in_date.days  due_in_date.month  \
# 0                      31        15                14                  1
# 1                      19        15                14                  1
# 2                      31        15                14                  1
# 3                      17        15                14                  1
# 4                      17        15                14                  1
# ...                   ...       ...               ...                ...
# 26123                  34        23                24                 10
# 26124                  53         0                 8                 10
# 26125                  10        32                 9                 11
# 26126                  29        35                12                 11
# 26127                  31        15                23                 10
#
#        due_in_date.year  baseline_create_date.days  \
# 0                  2019                         30
# 1                  2019                         30
# 2                  2019                         30
# 3                  2019                         30
# 4                  2019                         30
# ...                 ...                        ...
# 26123              2019                          1
# 26124              2019                          8
# 26125              2019                          8
# 26126              2019                          8
# 26127              2019                          8
#
#        baseline_create_date.month  baseline_create_date.year
# 0                              12                       2018
# 1                              12                       2018
# 2                              12                       2018
# 3                              12                       2018
# 4                              12                       2018
# ...                           ...                        ...
# 26123                          10                       2019
# 26124                          10                       2019
# 26125                          10                       2019
# 26126                          10                       2019
# 26127                          10                       2019
#
# [26128 rows x 12 columns]

# %% [markdown]
# # Modelling

# %% [markdown]
# ## create a base model

# %%
from sklearn.linear_model import LinearRegression
base_model = LinearRegression()
base_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_predict = base_model.predict(X_val)

# %%
from sklearn.metrics import mean_squared_error

mean_squared_error(y_val, y_predict, squared=False)
# Out:
# 6.4538613226284856

# %%
met = pd.DataFrame(zip(y_predict , y_val),columns=['Predicted','Actuals'])

# %% [markdown]
# ## Tree Based model

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0 , max_depth=5)

# %%
regressor.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5, random_state=0)

# %%
y_predict2 = regressor.predict(X_val)

# %%
mean_squared_error(y_val, y_predict2, squared=False)
# Out:
# 6.251170657957007

# %% [markdown]
# # Now predicting on the test set

# %%
y_predict_test = regressor.predict(X_test)
mean_squared_error(y_test, y_predict_test, squared=False)
# Out:
# 8.55941055523235

# %%
y_predict_test = base_model.predict(X_test)

# %%
mean_squared_error(y_val, y_predict2, squared=False)
# Out:
# 6.251170657957007

# %%
X_train
# Out:
#        business_code  cust_number  invoice_currency  total_open_amount  \
# 0                  1          656                 1             580.67
# 1                  1          724                 1           15284.38
# 2                  1          656                 1           28485.61
# 3                  1          564                 1             186.40
# 4                  1          288                 1           69249.78
# ...              ...          ...               ...                ...
# 26123              1          737                 1              70.80
# 26124              1         1116                 1            3956.54
# 26125              1          545                 1            3382.80
# 26126              1         1114                 1           26520.00
# 26127              1          656                 1            1898.20
#
#        cust_payment_terms  due_term  due_in_date.days  due_in_date.month  \
# 0                      31        15                14                  1
# 1                      19        15                14                  1
# 2                      31        15                14                  1
# 3                      17        15                14                  1
# 4                      17        15                14                  1
# ...                   ...       ...               ...                ...
# 26123                  34        23                24                 10
# 26124                  53         0                 8                 10
# 26125                  10        32                 9                 11
# 26126                  29        35                12                 11
# 26127                  31        15                23                 10
#
#        due_in_date.year  baseline_create_date.days  \
# 0                  2019                         30
# 1                  2019                         30
# 2                  2019                         30
# 3                  2019                         30
# 4                  2019                         30
# ...                 ...                        ...
# 26123              2019                          1
# 26124              2019                          8
# 26125              2019                          8
# 26126              2019                          8
# 26127              2019                          8
#
#        baseline_create_date.month  baseline_create_date.year
# 0                              12                       2018
# 1                              12                       2018
# 2                              12                       2018
# 3                              12                       2018
# 4                              12                       2018
# ...                           ...                        ...
# 26123                          10                       2019
# 26124                          10                       2019
# 26125                          10                       2019
# 26126                          10                       2019
# 26127                          10                       2019
#
# [26128 rows x 12 columns]

# %% [markdown]
# # Now on main_TEST set

# %%
main_test
# Out:
#       business_code cust_number      name_customer clear_date  buisness_year  \
# 2              U001  0200726979          BJ'S  llc        NaN         2020.0
# 9              U001   200418007         AM systems        NaN         2020.0
# 11             U001  0200900212           CASEY us        NaN         2020.0
# 16             U001  0200769623           WAL-MAR         NaN         2020.0
# 19             U001  0200984794           GREA llc        NaN         2020.0
# ...             ...         ...                ...        ...            ...
# 49993          U002  0200978592  PLAZA corporation        NaN         2020.0
# 49994          U001  0200936373         SUPE trust        NaN         2020.0
# 49996          U001  0200769623         WAL-MAR co        NaN         2020.0
# 49997          U001  0200769623         WAL-MAR in        NaN         2020.0
# 49998          U001  0200762301            C&S WH         NaN         2020.0
#
#              doc_id posting_date  document_create_date  \
# 2      1.930587e+09   2020-03-03              20200302
# 9      1.930841e+09   2020-05-01              20200430
# 11     1.930823e+09   2020-04-24              20200424
# 16     1.930834e+09   2020-04-29              20200428
# 19     1.930703e+09   2020-03-25              20200325
# ...             ...          ...                   ...
# 49993  1.990572e+09   2020-04-01              20200331
# 49994  1.930704e+09   2020-03-26              20200326
# 49996  1.930799e+09   2020-04-18              20200418
# 49997  1.930859e+09   2020-05-05              20200505
# 49998  1.930754e+09   2020-04-06              20200406
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 2                    20200303   20200318.0              USD            RV
# 9                    20200501   20200516.0              USD            RV
# 11                   20200424   20200509.0              USD            RV
# 16                   20200429   20200514.0              USD            RV
# 19                   20200325   20200409.0              USD            RV
# ...                       ...          ...              ...           ...
# 49993                20200401   20200506.0              USD            RV
# 49994                20200326   20200410.0              USD            RV
# 49996                20200418   20200503.0              USD            RV
# 49997                20200505   20200520.0              USD            RV
# 49998                20200406   20200421.0              USD            RV
#
#        posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 2             1.0             336.08            20200303.0               NAA8
# 9             1.0           33697.73            20200501.0               NAA8
# 11            1.0           24804.94            20200424.0               NAA8
# 16            1.0            4821.77            20200429.0               NAH4
# 19            1.0            8873.08            20200325.0               NAA8
# ...           ...                ...                   ...                ...
# 49993         1.0           55792.19            20200401.0               NAG2
# 49994         1.0           10912.65            20200326.0               NAA8
# 49996         1.0            2325.38            20200418.0               NAH4
# 49997         1.0           44462.63            20200505.0               NAH4
# 49998         1.0           74067.22            20200406.0               NAC6
#
#          invoice_id  isOpen
# 2      1.930587e+09       1
# 9      1.930841e+09       1
# 11     1.930823e+09       1
# 16     1.930834e+09       1
# 19     1.930703e+09       1
# ...             ...     ...
# 49993  1.990572e+09       1
# 49994  1.930704e+09       1
# 49996  1.930799e+09       1
# 49997  1.930859e+09       1
# 49998  1.930754e+09       1
#
# [10000 rows x 18 columns]

# %%
main_test.isna().sum()
# Out:
# business_code                 0
# cust_number                   0
# name_customer                 0
# clear_date                10000
# buisness_year                 0
# doc_id                        0
# posting_date                  0
# document_create_date          0
# document_create_date.1        0
# due_in_date                   0
# invoice_currency              0
# document type                 0
# posting_id                    0
# total_open_amount             0
# baseline_create_date          0
# cust_payment_terms            0
# invoice_id                    0
# isOpen                        0
# dtype: int64

# %%
X_main_test = main_test.drop(['clear_date'],axis=1)

# %%
X_main_test
# Out:
#       business_code cust_number      name_customer  buisness_year  \
# 2              U001  0200726979          BJ'S  llc         2020.0
# 9              U001   200418007         AM systems         2020.0
# 11             U001  0200900212           CASEY us         2020.0
# 16             U001  0200769623           WAL-MAR          2020.0
# 19             U001  0200984794           GREA llc         2020.0
# ...             ...         ...                ...            ...
# 49993          U002  0200978592  PLAZA corporation         2020.0
# 49994          U001  0200936373         SUPE trust         2020.0
# 49996          U001  0200769623         WAL-MAR co         2020.0
# 49997          U001  0200769623         WAL-MAR in         2020.0
# 49998          U001  0200762301            C&S WH          2020.0
#
#              doc_id posting_date  document_create_date  \
# 2      1.930587e+09   2020-03-03              20200302
# 9      1.930841e+09   2020-05-01              20200430
# 11     1.930823e+09   2020-04-24              20200424
# 16     1.930834e+09   2020-04-29              20200428
# 19     1.930703e+09   2020-03-25              20200325
# ...             ...          ...                   ...
# 49993  1.990572e+09   2020-04-01              20200331
# 49994  1.930704e+09   2020-03-26              20200326
# 49996  1.930799e+09   2020-04-18              20200418
# 49997  1.930859e+09   2020-05-05              20200505
# 49998  1.930754e+09   2020-04-06              20200406
#
#        document_create_date.1  due_in_date invoice_currency document type  \
# 2                    20200303   20200318.0              USD            RV
# 9                    20200501   20200516.0              USD            RV
# 11                   20200424   20200509.0              USD            RV
# 16                   20200429   20200514.0              USD            RV
# 19                   20200325   20200409.0              USD            RV
# ...                       ...          ...              ...           ...
# 49993                20200401   20200506.0              USD            RV
# 49994                20200326   20200410.0              USD            RV
# 49996                20200418   20200503.0              USD            RV
# 49997                20200505   20200520.0              USD            RV
# 49998                20200406   20200421.0              USD            RV
#
#        posting_id  total_open_amount  baseline_create_date cust_payment_terms  \
# 2             1.0             336.08            20200303.0               NAA8
# 9             1.0           33697.73            20200501.0               NAA8
# 11            1.0           24804.94            20200424.0               NAA8
# 16            1.0            4821.77            20200429.0               NAH4
# 19            1.0            8873.08            20200325.0               NAA8
# ...           ...                ...                   ...                ...
# 49993         1.0           55792.19            20200401.0               NAG2
# 49994         1.0           10912.65            20200326.0               NAA8
# 49996         1.0            2325.38            20200418.0               NAH4
# 49997         1.0           44462.63            20200505.0               NAH4
# 49998         1.0           74067.22            20200406.0               NAC6
#
#          invoice_id  isOpen
# 2      1.930587e+09       1
# 9      1.930841e+09       1
# 11     1.930823e+09       1
# 16     1.930834e+09       1
# 19     1.930703e+09       1
# ...             ...     ...
# 49993  1.990572e+09       1
# 49994  1.930704e+09       1
# 49996  1.930799e+09       1
# 49997  1.930859e+09       1
# 49998  1.930754e+09       1
#
# [10000 rows x 17 columns]

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### same step as in above main train set

# %%
# droping the constant features i.e document type ,posting_id,is_open
X_main_test = X_main_test.drop(columns = ['isOpen', 'posting_id','document type'])

# %%
#remove duplicate columns since invoice id and documnet id are the same
X_main_test= X_main_test.drop(columns=['doc_id'])

# %% [markdown]
# # Removing column having unique entries

# %%
# now since invice id in unique so we are going to drop it
X_main_test=X_main_test.drop(columns='invoice_id')

# %% [markdown]
# # Removing Irrelevent Columns

# %%
#now we are going to remove irrelevant columns which not effect predict model
X_main_test=X_main_test.drop(columns=['name_customer','document_create_date'])

# %% [markdown]
# # Date Time Conversion

# %%
X_main_test['document_create_date.1']=pd.to_datetime(X_main_test['document_create_date.1'], format='%Y%m%d')
X_main_test['due_in_date']=pd.to_datetime(X_main_test['due_in_date'], format='%Y%m%d')
X_main_test['baseline_create_date']=pd.to_datetime(X_main_test['baseline_create_date'], format='%Y%m%d')
X_main_test['posting_date']=pd.to_datetime(X_main_test['posting_date'])

# %% [markdown]
# # Sorting the entries by Posting date

# %%
X_main_test.sort_values(by=['posting_date'],inplace=True)

# %% [markdown]
# ### some invoices are created before baseline create date so we are removing those here

# %%
temp1 = pd.Series(X_main_test['document_create_date.1'] - X_main_test['baseline_create_date']).dt.days

# %%
rows_to_drop = temp1.value_counts().to_frame(name = 'count')

# %%
# No. of rows to drop satisfying the condition
rows_to_drop[(rows_to_drop.index <0)].sum()
# Out:
# count    583
# dtype: int64

# %%
X_main_test = X_main_test[((temp1==0) | (temp1>0))].reset_index(drop=True)

# %% [markdown]
# # now removing document_create_date.1 date since all the are now correct

# %%
X_main_test = X_main_test.drop(columns = ['document_create_date.1'])
X_main_test.dtypes , X_main_test.shape
# Out:
# (business_code                   object
#  cust_number                     object
#  buisness_year                  float64
#  posting_date            datetime64[ns]
#  due_in_date             datetime64[ns]
#  invoice_currency                object
#  total_open_amount              float64
#  baseline_create_date    datetime64[ns]
#  cust_payment_terms              object
#  dtype: object,
#  (9417, 9))

# %%
X_main_test['due_term']=pd.Series(X_main_test['due_in_date'] - X_main_test['baseline_create_date']).dt.days

# %%
X_main_test
# Out:
#      business_code cust_number  buisness_year posting_date due_in_date  \
# 0             U001  0200762950         2020.0   2020-02-27  2020-03-13
# 1             U001  0200726979         2020.0   2020-02-27  2020-03-13
# 2             U001  0200759878         2020.0   2020-02-27  2020-05-02
# 3             U001  0200063296         2020.0   2020-02-27  2020-03-28
# 4             U013  0100011958         2020.0   2020-02-27  2020-04-12
# ...            ...         ...            ...          ...         ...
# 9412          U001  0200712836         2020.0   2020-05-13  2020-05-28
# 9413          U001  0200413833         2020.0   2020-05-13  2020-05-28
# 9414          U001  0200762950         2020.0   2020-05-13  2020-05-28
# 9415          U001   200875680         2020.0   2020-05-13  2020-05-28
# 9416          CA02  0140104392         2020.0   2020-05-14  2020-05-24
#
#      invoice_currency  total_open_amount baseline_create_date  \
# 0                 USD          140884.32           2020-02-27
# 1                 USD              35.73           2020-02-27
# 2                 USD            7446.60           2020-02-27
# 3                 USD           20490.45           2020-02-27
# 4                 USD           10594.06           2020-02-27
# ...               ...                ...                  ...
# 9412              USD             589.76           2020-05-13
# 9413              USD           33140.44           2020-05-13
# 9414              USD          136025.60           2020-05-13
# 9415              USD           77253.74           2020-05-13
# 9416              CAD            7032.80           2020-05-14
#
#      cust_payment_terms  due_term
# 0                  NAA8        15
# 1                  NAA8        15
# 2                  NAGD        65
# 3                  NAD5        30
# 4                  NAVF        45
# ...                 ...       ...
# 9412               NAA8        15
# 9413               NAA8        15
# 9414               NAA8        15
# 9415               NAA8        15
# 9416               CA10        10
#
# [9417 rows x 10 columns]

# %% [markdown]
# # Label Encoding

# %%
# Again new classed are there in the main_test set
temp = set(X_main_test['business_code'])-set(business_code_encoder.classes_)
for items in temp:
    business_code_encoder.classes_= np.append(business_code_encoder.classes_,items)

X_main_test['business_code'] = business_code_encoder.transform(X_main_test['business_code'])

# %%
# Again new classed are there in the main_test set
temp1 = set(X_main_test['cust_number'])-set(cust_number_encoder.classes_)
for items in temp1:
    cust_number_encoder.classes_= np.append(cust_number_encoder.classes_,items)

X_main_test['cust_number'] = cust_number_encoder.transform(X_main_test['cust_number'])

# %%
# Again new classed are there in the main_test set
temp3 = set(X_main_test['invoice_currency'])-set(invoice_currency_encoder.classes_)
for items in temp3:
    invoice_currency_encoder.classes_= np.append(invoice_currency_encoder.classes_,items)

X_main_test['invoice_currency'] = invoice_currency_encoder.transform(X_main_test['invoice_currency'])

# %%
# Again new classed are there in the main_test set
temp4 = set(X_main_test['cust_payment_terms'])-set(cust_payment_terms_encoder.classes_)
for items in temp4:
    cust_payment_terms_encoder.classes_= np.append(cust_payment_terms_encoder.classes_,items)

X_main_test['cust_payment_terms'] = cust_payment_terms_encoder.transform(X_main_test['cust_payment_terms'])

# %%
X_main_test=X_main_test.drop(columns=['posting_date'])

# %%
X_main_test['due_in_date.days'] = X_main_test['due_in_date'].dt.day
X_main_test['due_in_date.month'] = X_main_test['due_in_date'].dt.month
X_main_test['due_in_date.year'] = X_main_test['due_in_date'].dt.year

# %%
X_main_test=X_main_test.drop(columns=['due_in_date'])

# %%
X_main_test['baseline_create_date.days'] = X_main_test['baseline_create_date'].dt.day
X_main_test['baseline_create_date.month'] = X_main_test['baseline_create_date'].dt.month
X_main_test['baseline_create_date.year'] = X_main_test['baseline_create_date'].dt.year

# %%
X_main_test=X_main_test.drop(columns=['baseline_create_date'])

# %%
#since we already know from corealtion matrix that business year is constant
X_main_test=X_main_test.drop(columns=['buisness_year'])

# %%
X_main_test
# Out:
#       business_code  cust_number  invoice_currency  total_open_amount  \
# 0                 1          643                 1          140884.32
# 1                 1          564                 1              35.73
# 2                 1          635                 1            7446.60
# 3                 1          304                 1           20490.45
# 4                 5           28                 1           10594.06
# ...             ...          ...               ...                ...
# 9412              1          540                 1             589.76
# 9413              1          417                 1           33140.44
# 9414              1          643                 1          136025.60
# 9415              1         1239                 1           77253.74
# 9416              0         1267                 0            7032.80
#
#       cust_payment_terms  due_term  due_in_date.days  due_in_date.month  \
# 0                     17        15                13                  3
# 1                     17        15                13                  3
# 2                     30        65                 2                  5
# 3                     27        30                28                  3
# 4                     45        45                12                  4
# ...                  ...       ...               ...                ...
# 9412                  17        15                28                  5
# 9413                  17        15                28                  5
# 9414                  17        15                28                  5
# 9415                  17        15                28                  5
# 9416                   4        10                24                  5
#
#       due_in_date.year  baseline_create_date.days  baseline_create_date.month  \
# 0                 2020                         27                           2
# 1                 2020                         27                           2
# 2                 2020                         27                           2
# 3                 2020                         27                           2
# 4                 2020                         27                           2
# ...                ...                        ...                         ...
# 9412              2020                         13                           5
# 9413              2020                         13                           5
# 9414              2020                         13                           5
# 9415              2020                         13                           5
# 9416              2020                         14                           5
#
#       baseline_create_date.year
# 0                          2020
# 1                          2020
# 2                          2020
# 3                          2020
# 4                          2020
# ...                         ...
# 9412                       2020
# 9413                       2020
# 9414                       2020
# 9415                       2020
# 9416                       2020
#
# [9417 rows x 12 columns]

# %%
X_main_test.columns
# Out:
# Index(['business_code', 'cust_number', 'invoice_currency', 'total_open_amount',
#        'cust_payment_terms', 'due_term', 'due_in_date.days',
#        'due_in_date.month', 'due_in_date.year', 'baseline_create_date.days',
#        'baseline_create_date.month', 'baseline_create_date.year'],
#       dtype='object')

# %%
X_train.columns
# Out:
# Index(['business_code', 'cust_number', 'invoice_currency', 'total_open_amount',
#        'cust_payment_terms', 'due_term', 'due_in_date.days',
#        'due_in_date.month', 'due_in_date.year', 'baseline_create_date.days',
#        'baseline_create_date.month', 'baseline_create_date.year'],
#       dtype='object')

# %% [markdown]
# # Final Prediction

# %%
final_result = regressor.predict(X_main_test)

# %%
final_result = pd.Series(final_result,name='delay')

# %%
# resetting the index of main test so that we can merge price series with it
main_test.reset_index(drop=True,inplace=True)

# %%
main_test
# Out:
#      business_code cust_number      name_customer clear_date  buisness_year  \
# 0             U001  0200726979          BJ'S  llc        NaN         2020.0
# 1             U001   200418007         AM systems        NaN         2020.0
# 2             U001  0200900212           CASEY us        NaN         2020.0
# 3             U001  0200769623           WAL-MAR         NaN         2020.0
# 4             U001  0200984794           GREA llc        NaN         2020.0
# ...            ...         ...                ...        ...            ...
# 9995          U002  0200978592  PLAZA corporation        NaN         2020.0
# 9996          U001  0200936373         SUPE trust        NaN         2020.0
# 9997          U001  0200769623         WAL-MAR co        NaN         2020.0
# 9998          U001  0200769623         WAL-MAR in        NaN         2020.0
# 9999          U001  0200762301            C&S WH         NaN         2020.0
#
#             doc_id posting_date  document_create_date  document_create_date.1  \
# 0     1.930587e+09   2020-03-03              20200302                20200303
# 1     1.930841e+09   2020-05-01              20200430                20200501
# 2     1.930823e+09   2020-04-24              20200424                20200424
# 3     1.930834e+09   2020-04-29              20200428                20200429
# 4     1.930703e+09   2020-03-25              20200325                20200325
# ...            ...          ...                   ...                     ...
# 9995  1.990572e+09   2020-04-01              20200331                20200401
# 9996  1.930704e+09   2020-03-26              20200326                20200326
# 9997  1.930799e+09   2020-04-18              20200418                20200418
# 9998  1.930859e+09   2020-05-05              20200505                20200505
# 9999  1.930754e+09   2020-04-06              20200406                20200406
#
#       due_in_date invoice_currency document type  posting_id  \
# 0      20200318.0              USD            RV         1.0
# 1      20200516.0              USD            RV         1.0
# 2      20200509.0              USD            RV         1.0
# 3      20200514.0              USD            RV         1.0
# 4      20200409.0              USD            RV         1.0
# ...           ...              ...           ...         ...
# 9995   20200506.0              USD            RV         1.0
# 9996   20200410.0              USD            RV         1.0
# 9997   20200503.0              USD            RV         1.0
# 9998   20200520.0              USD            RV         1.0
# 9999   20200421.0              USD            RV         1.0
#
#       total_open_amount  baseline_create_date cust_payment_terms  \
# 0                336.08            20200303.0               NAA8
# 1              33697.73            20200501.0               NAA8
# 2              24804.94            20200424.0               NAA8
# 3               4821.77            20200429.0               NAH4
# 4               8873.08            20200325.0               NAA8
# ...                 ...                   ...                ...
# 9995           55792.19            20200401.0               NAG2
# 9996           10912.65            20200326.0               NAA8
# 9997            2325.38            20200418.0               NAH4
# 9998           44462.63            20200505.0               NAH4
# 9999           74067.22            20200406.0               NAC6
#
#         invoice_id  isOpen
# 0     1.930587e+09       1
# 1     1.930841e+09       1
# 2     1.930823e+09       1
# 3     1.930834e+09       1
# 4     1.930703e+09       1
# ...            ...     ...
# 9995  1.990572e+09       1
# 9996  1.930704e+09       1
# 9997  1.930799e+09       1
# 9998  1.930859e+09       1
# 9999  1.930754e+09       1
#
# [10000 rows x 18 columns]

# %%
main_test['document_create_date.1']=pd.to_datetime(main_test['document_create_date.1'], format='%Y%m%d')
main_test['due_in_date']=pd.to_datetime(main_test['due_in_date'], format='%Y%m%d')
main_test['baseline_create_date']=pd.to_datetime(main_test['baseline_create_date'], format='%Y%m%d')
main_test['posting_date']=pd.to_datetime(main_test['posting_date'])

# %% [markdown]
# # some invoices are created before baseline create date so we are removing those here

# %%
temp_main = pd.Series(main_test['document_create_date.1'] - main_test['baseline_create_date']).dt.days
temp_main = pd.Series(main_test['document_create_date.1'] - main_test['baseline_create_date']).dt.days
rows_to_drop = temp_main.value_counts().to_frame(name = 'count')

# %%
# No. of rows to drop satisfying the condition
rows_to_drop[(rows_to_drop.index <0)].sum()
# Out:
# count    583
# dtype: int64

# %%
main_test = main_test[((temp_main==0) | (temp_main>0))].reset_index(drop=True)

# %% [markdown]
# # Below table showing delays in payment mapped against Main_test

# %%
Final = main_test.merge(final_result , on = X_main_test.index )
Final
# Out:
#       key_0 business_code cust_number      name_customer clear_date  \
# 0         0          U001  0200726979          BJ'S  llc        NaN
# 1         1          U001   200418007         AM systems        NaN
# 2         2          U001  0200900212           CASEY us        NaN
# 3         3          U001  0200769623           WAL-MAR         NaN
# 4         4          U001  0200984794           GREA llc        NaN
# ...     ...           ...         ...                ...        ...
# 9412   9412          U002  0200978592  PLAZA corporation        NaN
# 9413   9413          U001  0200936373         SUPE trust        NaN
# 9414   9414          U001  0200769623         WAL-MAR co        NaN
# 9415   9415          U001  0200769623         WAL-MAR in        NaN
# 9416   9416          U001  0200762301            C&S WH         NaN
#
#       buisness_year        doc_id posting_date  document_create_date  \
# 0            2020.0  1.930587e+09   2020-03-03              20200302
# 1            2020.0  1.930841e+09   2020-05-01              20200430
# 2            2020.0  1.930823e+09   2020-04-24              20200424
# 3            2020.0  1.930834e+09   2020-04-29              20200428
# 4            2020.0  1.930703e+09   2020-03-25              20200325
# ...             ...           ...          ...                   ...
# 9412         2020.0  1.990572e+09   2020-04-01              20200331
# 9413         2020.0  1.930704e+09   2020-03-26              20200326
# 9414         2020.0  1.930799e+09   2020-04-18              20200418
# 9415         2020.0  1.930859e+09   2020-05-05              20200505
# 9416         2020.0  1.930754e+09   2020-04-06              20200406
#
#      document_create_date.1 due_in_date invoice_currency document type  \
# 0                2020-03-03  2020-03-18              USD            RV
# 1                2020-05-01  2020-05-16              USD            RV
# 2                2020-04-24  2020-05-09              USD            RV
# 3                2020-04-29  2020-05-14              USD            RV
# 4                2020-03-25  2020-04-09              USD            RV
# ...                     ...         ...              ...           ...
# 9412             2020-04-01  2020-05-06              USD            RV
# 9413             2020-03-26  2020-04-10              USD            RV
# 9414             2020-04-18  2020-05-03              USD            RV
# 9415             2020-05-05  2020-05-20              USD            RV
# 9416             2020-04-06  2020-04-21              USD            RV
#
#       posting_id  total_open_amount baseline_create_date cust_payment_terms  \
# 0            1.0             336.08           2020-03-03               NAA8
# 1            1.0           33697.73           2020-05-01               NAA8
# 2            1.0           24804.94           2020-04-24               NAA8
# 3            1.0            4821.77           2020-04-29               NAH4
# 4            1.0            8873.08           2020-03-25               NAA8
# ...          ...                ...                  ...                ...
# 9412         1.0           55792.19           2020-04-01               NAG2
# 9413         1.0           10912.65           2020-03-26               NAA8
# 9414         1.0            2325.38           2020-04-18               NAH4
# 9415         1.0           44462.63           2020-05-05               NAH4
# 9416         1.0           74067.22           2020-04-06               NAC6
#
#         invoice_id  isOpen      delay
# 0     1.930587e+09       1   1.014486
# 1     1.930841e+09       1   1.014486
# 2     1.930823e+09       1  -4.244582
# 3     1.930834e+09       1   7.031008
# 4     1.930703e+09       1  -5.397490
# ...            ...     ...        ...
# 9412  1.990572e+09       1   1.014486
# 9413  1.930704e+09       1   1.014486
# 9414  1.930799e+09       1   1.014486
# 9415  1.930859e+09       1  33.412500
# 9416  1.930754e+09       1  39.928571
#
# [9417 rows x 20 columns]

# %% [markdown]
# # Calculating Predicted Payment Date

# %%
from datetime import timedelta, date

# %%
Final['INVOICE PAYMENT TERM']=Final['delay']

# %%
Final['Predicted PAYMENT DATE'] = Final['due_in_date'] + pd.to_timedelta(np.ceil(Final['INVOICE PAYMENT TERM']),'D')

# %%
Final = Final.drop(['INVOICE PAYMENT TERM'],axis=1)

# %%
Final.nunique()
# Out:
# key_0                     9417
# business_code                5
# cust_number                602
# name_customer             1555
# clear_date                   0
# buisness_year                1
# doc_id                    9153
# posting_date                78
# document_create_date        87
# document_create_date.1      78
# due_in_date                127
# invoice_currency             2
# document type                1
# posting_id                   1
# total_open_amount         8560
# baseline_create_date        80
# cust_payment_terms          36
# invoice_id                9153
# isOpen                       1
# delay                       23
# Predicted PAYMENT DATE     145
# dtype: int64

# %%
def Ageing_Bucket(x):
    if x<0:
        return('(< 0) Days')
    if x in range(0,16):
        return('(0-15) Days')
    elif x in range(16,31):
        return('(16-30) Days')
    elif x in range(31,45):
        return('(31-45) Days')
    elif x in range(45,60):
        return('(45-60) Days')
    else:
        return('(> 60) Days')

# %%
Final['Ageing Bucket']= pd.Series([Ageing_Bucket(x=int(Final['delay'][i]))  for i in range(len(Final))])

# %%
Final
# Out:
#       key_0 business_code cust_number      name_customer clear_date  \
# 0         0          U001  0200726979          BJ'S  llc        NaN
# 1         1          U001   200418007         AM systems        NaN
# 2         2          U001  0200900212           CASEY us        NaN
# 3         3          U001  0200769623           WAL-MAR         NaN
# 4         4          U001  0200984794           GREA llc        NaN
# ...     ...           ...         ...                ...        ...
# 9412   9412          U002  0200978592  PLAZA corporation        NaN
# 9413   9413          U001  0200936373         SUPE trust        NaN
# 9414   9414          U001  0200769623         WAL-MAR co        NaN
# 9415   9415          U001  0200769623         WAL-MAR in        NaN
# 9416   9416          U001  0200762301            C&S WH         NaN
#
#       buisness_year        doc_id posting_date  document_create_date  \
# 0            2020.0  1.930587e+09   2020-03-03              20200302
# 1            2020.0  1.930841e+09   2020-05-01              20200430
# 2            2020.0  1.930823e+09   2020-04-24              20200424
# 3            2020.0  1.930834e+09   2020-04-29              20200428
# 4            2020.0  1.930703e+09   2020-03-25              20200325
# ...             ...           ...          ...                   ...
# 9412         2020.0  1.990572e+09   2020-04-01              20200331
# 9413         2020.0  1.930704e+09   2020-03-26              20200326
# 9414         2020.0  1.930799e+09   2020-04-18              20200418
# 9415         2020.0  1.930859e+09   2020-05-05              20200505
# 9416         2020.0  1.930754e+09   2020-04-06              20200406
#
#      document_create_date.1  ... document type posting_id total_open_amount  \
# 0                2020-03-03  ...            RV        1.0            336.08
# 1                2020-05-01  ...            RV        1.0          33697.73
# 2                2020-04-24  ...            RV        1.0          24804.94
# 3                2020-04-29  ...            RV        1.0           4821.77
# 4                2020-03-25  ...            RV        1.0           8873.08
# ...                     ...  ...           ...        ...               ...
# 9412             2020-04-01  ...            RV        1.0          55792.19
# 9413             2020-03-26  ...            RV        1.0          10912.65
# 9414             2020-04-18  ...            RV        1.0           2325.38
# 9415             2020-05-05  ...            RV        1.0          44462.63
# 9416             2020-04-06  ...            RV        1.0          74067.22
#
#       baseline_create_date  cust_payment_terms    invoice_id isOpen  \
# 0               2020-03-03                NAA8  1.930587e+09      1
# 1               2020-05-01                NAA8  1.930841e+09      1
# 2               2020-04-24                NAA8  1.930823e+09      1
# 3               2020-04-29                NAH4  1.930834e+09      1
# 4               2020-03-25                NAA8  1.930703e+09      1
# ...                    ...                 ...           ...    ...
# 9412            2020-04-01                NAG2  1.990572e+09      1
# 9413            2020-03-26                NAA8  1.930704e+09      1
# 9414            2020-04-18                NAH4  1.930799e+09      1
# 9415            2020-05-05                NAH4  1.930859e+09      1
# 9416            2020-04-06                NAC6  1.930754e+09      1
#
#           delay  Predicted PAYMENT DATE  Ageing Bucket
# 0      1.014486              2020-03-20    (0-15) Days
# 1      1.014486              2020-05-18    (0-15) Days
# 2     -4.244582              2020-05-05     (< 0) Days
# 3      7.031008              2020-05-22    (0-15) Days
# 4     -5.397490              2020-04-04     (< 0) Days
# ...         ...                     ...            ...
# 9412   1.014486              2020-05-08    (0-15) Days
# 9413   1.014486              2020-04-12    (0-15) Days
# 9414   1.014486              2020-05-05    (0-15) Days
# 9415  33.412500              2020-06-23   (31-45) Days
# 9416  39.928571              2020-05-31   (31-45) Days
#
# [9417 rows x 22 columns]

# %%
Final = Final.drop(['key_0'],axis=1)

# %%
Final.head(200)
# Out:
#     business_code cust_number name_customer clear_date  buisness_year  \
# 0            U001  0200726979     BJ'S  llc        NaN         2020.0
# 1            U001   200418007    AM systems        NaN         2020.0
# 2            U001  0200900212      CASEY us        NaN         2020.0
# 3            U001  0200769623      WAL-MAR         NaN         2020.0
# 4            U001  0200984794      GREA llc        NaN         2020.0
# ..            ...         ...           ...        ...            ...
# 195          U001   200936373    SUPE trust        NaN         2020.0
# 196          U001  0200726979     BJ'S  llc        NaN         2020.0
# 197          U001  0200592182     DECA corp        NaN         2020.0
# 198          U001  0200726979      BJ'S  in        NaN         2020.0
# 199          U001  0200762301     C&S WH us        NaN         2020.0
#
#            doc_id posting_date  document_create_date document_create_date.1  \
# 0    1.930587e+09   2020-03-03              20200302             2020-03-03
# 1    1.930841e+09   2020-05-01              20200430             2020-05-01
# 2    1.930823e+09   2020-04-24              20200424             2020-04-24
# 3    1.930834e+09   2020-04-29              20200428             2020-04-29
# 4    1.930703e+09   2020-03-25              20200325             2020-03-25
# ..            ...          ...                   ...                    ...
# 195  1.930632e+09   2020-03-10              20200310             2020-03-10
# 196  1.930780e+09   2020-04-12              20200413             2020-04-12
# 197  1.930638e+09   2020-03-11              20200311             2020-03-11
# 198  1.930723e+09   2020-03-31              20200331             2020-03-31
# 199  1.930606e+09   2020-03-06              20200305             2020-03-06
#
#     due_in_date  ... document type posting_id  total_open_amount  \
# 0    2020-03-18  ...            RV        1.0             336.08
# 1    2020-05-16  ...            RV        1.0           33697.73
# 2    2020-05-09  ...            RV        1.0           24804.94
# 3    2020-05-14  ...            RV        1.0            4821.77
# 4    2020-04-09  ...            RV        1.0            8873.08
# ..          ...  ...           ...        ...                ...
# 195  2020-05-14  ...            RV        1.0           18224.92
# 196  2020-04-27  ...            RV        1.0            1361.10
# 197  2020-03-24  ...            RV        1.0              54.00
# 198  2020-04-15  ...            RV        1.0             750.26
# 199  2020-03-21  ...            RV        1.0            3946.13
#
#      baseline_create_date cust_payment_terms    invoice_id  isOpen     delay  \
# 0              2020-03-03               NAA8  1.930587e+09       1  1.014486
# 1              2020-05-01               NAA8  1.930841e+09       1  1.014486
# 2              2020-04-24               NAA8  1.930823e+09       1 -4.244582
# 3              2020-04-29               NAH4  1.930834e+09       1  7.031008
# 4              2020-03-25               NAA8  1.930703e+09       1 -5.397490
# ..                    ...                ...           ...     ...       ...
# 195            2020-03-10               NAGD  1.930632e+09       1  1.014486
# 196            2020-04-12               NAA8  1.930780e+09       1 -1.899685
# 197            2020-03-01               NAM4  1.930638e+09       1  1.014486
# 198            2020-03-31               NAA8  1.930723e+09       1 -1.899685
# 199            2020-03-06               NAC6  1.930606e+09       1  1.014486
#
#      Predicted PAYMENT DATE Ageing Bucket
# 0                2020-03-20   (0-15) Days
# 1                2020-05-18   (0-15) Days
# 2                2020-05-05    (< 0) Days
# 3                2020-05-22   (0-15) Days
# 4                2020-04-04    (< 0) Days
# ..                      ...           ...
# 195              2020-05-16   (0-15) Days
# 196              2020-04-26    (< 0) Days
# 197              2020-03-26   (0-15) Days
# 198              2020-04-14    (< 0) Days
# 199              2020-03-23   (0-15) Days
#
# [200 rows x 21 columns]
